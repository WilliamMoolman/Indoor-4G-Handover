# %%
import sys

sys.path.append("..")

from importlib import reload
import utils.log_viewer

reload(utils.log_viewer)
from utils.log_viewer import plot_experiment

# %matplotlib widget

# %% [markdown]
# # Experiments performed:
#
# - 20240312_1143: stationary @ (2.5,2) with UDP
# - 20240312_1150:
# - 20240312_1154:
# - 20240312_1200:
# - 20240312_1205:
# - 20240312_1210:
# - 20240312_1225:
# - 20240312_1247:
# - 20240312_1257:
# - 20240312_1306:
# - 20240312_1310:
# - 20240312_1312:
# - 20240312_1315:
# - 20240312_1316:

# %%
# 20240312_1107

experiment = "20240322_1107"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} Hyst 0",
    save_path="../figs/5hyst0.png",
)

# %%
# 20240312_1113

experiment = "20240322_1113"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:16:40",
    # to_time="11:17:00",
    title=f"{experiment} Hyst 3",
    save_path="../figs/5hyst3.png",
)

# %%
# 20240312_1121

experiment = "20240322_1121"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} Hyst 6",
    save_path="../figs/5hyst6.png",
)

# %%
# 20240312_1139

experiment = "20240322_1139"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} Hyst 9",
    save_path="../figs/5hyst9.png",
)

# %%
# 20240312_1153

experiment = "20240322_1153"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} ??",
)

# %%
# 20240312_1158

experiment = "20240322_1158"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} ??",
)

# %%
# 20240322_1202

experiment = "20240322_1202"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} ??",
)

# %%
# 20240322_1212

experiment = "20240322_1212"

plot_experiment(
    f"data/logs/{experiment}.log",
    None,
    # from_time="11:47:37",
    # to_time="11:48:12",
    title=f"{experiment} ??",
)
