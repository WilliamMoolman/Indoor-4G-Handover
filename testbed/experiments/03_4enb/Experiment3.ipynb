# %%
import sys

sys.path.append("..")

from importlib import reload
import utils.log_viewer

reload(utils.log_viewer)
from utils.log_viewer import plot_experiment

# %matplotlib widget

# %%
experiment = "walking1"

plot_experiment(
    f"data/{experiment}/enb.log",
    None,  # f"data/{experiment}/iperf.csv",
    title=f"Experiment 1 - Walk (No Throughput)",
    save_path=f"../figs/5walking1.png",
)

# %%
experiment = "stationary"

plot_experiment(
    f"data/{experiment}/enb.log",
    None,  # f"data/{experiment}/iperf.csv",
    from_time="12:19:40",
    to_time="12:21:14",
    title=f"Stationary",
    save_path=f"../figs/5stationary.png",
)

plot_experiment(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="12:19:40",
    to_time="12:21:14",
    title=f"Stationary",
    save_path=f"../figs/5stationary_throughput.png",
)

# %%
experiment = "walking2"

plot_experiment(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    title=f"",  #
    from_time="13:07:00",
    to_time="13:08:45",
    reset_ticks=True,
    print_ho=True,
    # save_path=f"../figs/3NEW2",
    print_stats=True,
)
# Out:
# Handover from 4 to 2 @ 2024-03-05 13:07:10.644494
# Handover from 2 to 4 @ 2024-03-05 13:07:41.472619
# Handover from 4 to 2 @ 2024-03-05 13:07:43.864429
# Handover from 2 to 4 @ 2024-03-05 13:07:54.213523
# Handover from 4 to 2 @ 2024-03-05 13:07:57.063439
# Handover from 2 to 4 @ 2024-03-05 13:07:57.633560
# Handover from 4 to 1 @ 2024-03-05 13:08:16.302897
# Handover from 1 to 4 @ 2024-03-05 13:08:45.110230
# == Total Corr ==
# 0.13042914173841333
#
# == Per-pci corr ==
# pci
# 1    rsrp   -0.017351
# 2    rsrp    0.438473
# 4    rsrp    0.456598
# Name: length, dtype: float64
#
# == Average throughput per PCI ==
# pci
# 1    6.054433
# 2    1.729332
# 4    4.079520
# Name: length, dtype: float64

# %%
experiment = "walking3"
import datetime

plot_experiment(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    title=f"",  # Random Walk",
    reset_ticks=True,
    print_stats=True,
    # print_ho=True,
    # save_path=f"../figs/3NEW3",
)
# plot_experiment(
#     f"data/{experiment}/enb.log",
#     None,  # f"data/{experiment}/iperf.csv",
#     title=f"Random Walk",
#     # print_ho=True,
#     save_path=f"../figs/5walking3.png",
# )
# # first: 13:28:07.843158, last: 13:39:31.036457
# seconds_between = datetime.datetime.strptime("13:39:31", "%H:%M:%S") - datetime.datetime.strptime("13:28:07", "%H:%M:%S")
# 29 / seconds_between.total_seconds() * 60
# Out:
# == Total Corr ==
# 0.04123229471237932
#
# == Per-pci corr ==
# pci
# 2.0  rsrp    0.300275
# 3.0  rsrp    0.507215
# 4.0  rsrp    0.228896
# Name: length, dtype: float64
#
# == Average throughput per PCI ==
# pci
# 2.0    2.472541
# 3.0    8.209316
# 4.0    3.515655
# Name: length, dtype: float64

# %%
experiment = "walking4"

plot_experiment(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="14:19:20",
    to_time="14:20:43",
    title=f"",
    reset_ticks=True,
    print_stats=True,
    # save_path=f"../figs/3New4",
)
# Out:
# == Total Corr ==
# 0.5015771252235253
#
# == Per-pci corr ==
# pci
# 1.0  rsrp   -0.137235
# 2.0  rsrp    0.700647
# 4.0  rsrp    0.684696
# Name: length, dtype: float64
#
# == Average throughput per PCI ==
# pci
# 1.0    2.740689
# 2.0    1.598098
# 4.0    4.344704
# Name: length, dtype: float64

# %%
experiment = "failed"

plot_experiment(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="14:33:45",
    to_time="14:34:00",
    title=f"Failed Experiment",
)
