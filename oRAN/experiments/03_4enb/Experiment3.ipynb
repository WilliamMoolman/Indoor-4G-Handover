# %%
import sys

sys.path.append("..")

from importlib import reload
import utils.log_viewer

reload(utils.log_viewer)
from utils.log_viewer import plot_experiment, plot_experiment_subplots

# %matplotlib widget

# %%
experiment = "walking1"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    title=f"Experiment 1 - Walk (No Throughput)",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
experiment = "stationary"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="12:19:40",
    to_time="12:21:14",
    title=f"Experiment 1 - Stationary",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
experiment = "walking2"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    title=f"Experiment 3 - Walk",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
experiment = "walking3"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    title=f"Experiment 3 - Random Walk",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
experiment = "walking4"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="14:19:20",
    to_time="14:20:43",
    title=f"Experiment 2 - Random Walk",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
experiment = "failed"

plot_experiment_subplots(
    f"data/{experiment}/enb.log",
    f"data/{experiment}/iperf.csv",
    from_time="14:33:45",
    to_time="14:34:00",
    title=f"Failed Experiment",
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
